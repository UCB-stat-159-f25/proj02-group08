# %%
import this

# %%
import antigravity

# %%
from __future__ import braces
# Out:
#   Cell In[16], line 1
#     from __future__ import braces
#     ^
# SyntaxError: not a chance

# %%
import __hello__

# %%
from __future__ import barry_as_FLUFL

# %%
import rick
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import rick
#
# ModuleNotFoundError: No module named 'rick'

# %%
hash(brownie)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 hash(brownie)
#
# NameError: name 'brownie' is not defined

# %%
# testing comments
